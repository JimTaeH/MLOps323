# %%
# send raw HTTP request to test the web service.
import requests

import requests
from PIL import Image
from io import BytesIO

# %%
headers = {"Content-Type": "application/json"}
# Change Endpoint Here
endpoint_url = 'http://9879b9bb-3593-4503-8ba6-4d821f6d158d.eastus2.azurecontainer.io/score'

# %%
# send a random row from the test set to score
input_data = "https://images.hindustantimes.com/rf/image_size_630x354/HT/p2/2019/07/22/Pictures/manhole_571c2afa-ac07-11e9-8ce3-2af94b9ec815.jpg"
response = requests.get(input_data)
img = Image.open(BytesIO(response.content))
img = img.resize((180, 180))
img
# Out:
# <PIL.Image.Image image mode=RGB size=180x180 at 0x24C8E4BE088>

# %%
resp = requests.post(endpoint_url, input_data, headers=headers)

print("POST to url", endpoint_url)
print("prediction:", resp.text)
# Out:
# POST to url http://9879b9bb-3593-4503-8ba6-4d821f6d158d.eastus2.azurecontainer.io/score
# prediction: "safety with confidence 100.0%"
